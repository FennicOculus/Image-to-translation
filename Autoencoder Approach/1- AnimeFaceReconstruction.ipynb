# %% [markdown]
# #Downloading Dataset

# %%
# !cp -r /content/drive/MyDrive/Kaggle/kaggle.json /content/

# %%
! pip install -q kaggle

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory

# %% [markdown]
# I used the anime face dataset on [Kaggle](https://www.kaggle.com/datasets/splcher/animefacedataset) provided by splcher

# %%
# !kaggle datasets download 'splcher/animefacedataset'
# !unzip animefacedataset.zip

# %% [markdown]
# #Importing Libraries

# %%
from keras.layers import BatchNormalization
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Input
from keras.layers import Dropout
from keras.models import Model
from keras import backend as K
from keras.layers import Rescaling, Resizing
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LambdaCallback, TensorBoard, BackupAndRestore
from keras import regularizers
import numpy as np
import os
import datetime
import gc #garbage collector
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import cv2
import psutil
from random import shuffle

# %%
wannaTrain = True
scratch = True

# %% [markdown]
# Checking if i'm using GPU or CPU

# %%
device_name = tf.test.gpu_device_name()
if len(device_name) > 0:
    print("Found GPU at: {}".format(device_name))
else:
    device_name = "/device:CPU:0"
    print("No GPU, using {}.".format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# #Dataset Preprocessing

# %% [markdown]
# All images are squared so we just define one dim and use it twice

# %%
hight = 64

# %%
path_to_img = "/content/images/"

# %% [markdown]
# Loading images paths

# %%
dataset = [path_to_img + i for i in os.listdir(path_to_img)]
print(len(dataset))
print(dataset[:3])
# Out:
# 63565
# ['/content/images/52892_2016.jpg', '/content/images/44343_2013.jpg', '/content/images/52408_2015.jpg']

# %%
shuffle(dataset)

# %%
split_index = int(0.75 * len(dataset))
ae_train, ae_test = np.split(dataset, [split_index])

# %%
split_index = int(0.8 * len(ae_train))
ae_train, ae_vali= np.split(ae_train, [split_index])

# %% [markdown]
# Creating the dataset

# %%
ae_dataset = []
for i in tqdm(dataset):
  ae_dataset.append(cv2.resize(np.array(cv2.imread(i)[:,:,::-1]),(hight, hight)).astype("float32")/255.0)
# Out:
# 100%|██████████| 63565/63565 [00:53<00:00, 1196.88it/s]

# %%
ae_dataset = np.array(ae_dataset)

# %%
ae_dataset.shape
# Out:
# (63565, 64, 64, 3)

# %% [markdown]
# We create the train and test sets

# %%
np.random.shuffle(ae_dataset)

# %%
split_index = int(0.70 * len(ae_dataset))
ae_train, ae_test = np.split(ae_dataset, [split_index])

# %%
split_index = int(0.8 * len(ae_train))
ae_train, ae_vali= np.split(ae_train, [split_index])

# %%
ae_train.shape, ae_test.shape, ae_vali.shape
# Out:
# ((35596, 64, 64, 3), (19070, 64, 64, 3), (8899, 64, 64, 3))

# %%
np.save('ae_train', ae_train)
np.save('ae_test', ae_test)
np.save('ae_vali', ae_vali)

# %% [markdown]
# Show some exemples

# %%
fig, ax = plt.subplots(2, 5, figsize=(15, 6))
for i in range(2):
    for j in range(5):
      ax[i, j].imshow(ae_train[i*5 + j])
      ax[i, j].axis('off')
      ax[i, j].set_title(f'Image {i*5 + j + 1}')
plt.show()

# %% [markdown]
# Delete to free some ram space

# %%
del ae_dataset
del ae_train
del ae_test
del ae_vali

# %%
gc.collect()
# Out:
# 45

# %% [markdown]
# #Encoder Part

# %%
latentDim = 2048
inputShape = (hight, hight, 3)
chanDim = 3
depth = 1

# %%
inputs = Input(shape=inputShape)
x = inputs


x = Conv2D(256, (3, 3), strides=2, padding="same")(x)
x = LeakyReLU(alpha=0.2)(x)
x = BatchNormalization(axis=chanDim)(x)

x = Conv2D(128, (3, 3), strides=2, padding="same")(x)
x = LeakyReLU(alpha=0.2)(x)
x = BatchNormalization(axis=chanDim)(x)

x = Conv2D(64, (3, 3), strides=2, padding="same")(x)
x = LeakyReLU(alpha=0.2)(x)
x = BatchNormalization(axis=chanDim)(x)

volumeSize = K.int_shape(x)
x = Flatten()(x)
# x = Dense(4096, activation='relu')(x)
# x = Dense(2048, activation='relu')(x)
latent = Dense(latentDim)(x)

# %%
encoder = Model(inputs, latent, name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 256)       7168
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 256)       0
#
#  batch_normalization (BatchN  (None, 32, 32, 256)      1024
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 128)       295040
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  batch_normalization_1 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          73792
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 2048)              8390656
#
# =================================================================
# Total params: 8,768,448
# Trainable params: 8,767,552
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# #Decoder part

# %%
latentInputs = Input(shape=(latentDim,))
# x = Dense(2048, activation='relu')(latentInputs)
# x = Dense(4096, activation='relu')(x)
x = Dense(np.prod(volumeSize[1:]))(latentInputs)
x = Reshape((volumeSize[1], volumeSize[2], volumeSize[3]))(x)

# %%
x = Conv2DTranspose(64, (3, 3), strides=2, padding="same")(x)
x = LeakyReLU(alpha=0.2)(x)
x = BatchNormalization(axis=chanDim)(x)

x = Conv2DTranspose(128, (3, 3), strides=2, padding="same")(x)
x = LeakyReLU(alpha=0.2)(x)
x = BatchNormalization(axis=chanDim)(x)

x = Conv2DTranspose(256, (3, 3), strides=2, padding="same")(x)
x = LeakyReLU(alpha=0.2)(x)
x = BatchNormalization(axis=chanDim)(x)

x = Conv2DTranspose(3, (3, 3), padding="same")(x)
outputs = Activation("sigmoid")(x)

# %%
decoder = Model(latentInputs, outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2048)]            0
#
#  dense_1 (Dense)             (None, 4096)              8392704
#
#  reshape (Reshape)           (None, 8, 8, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 16, 16, 64)       36928
#  nspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 128)      73856
#  ranspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  batch_normalization_4 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 256)      295168
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 64, 64, 256)       0
#
#  batch_normalization_5 (Batc  (None, 64, 64, 256)      1024
#  hNormalization)
#
#  conv2d_transpose_3 (Conv2DT  (None, 64, 64, 3)        6915
#  ranspose)
#
#  activation (Activation)     (None, 64, 64, 3)         0
#
# =================================================================
# Total params: 8,807,363
# Trainable params: 8,806,467
# Non-trainable params: 896
# _________________________________________________________________

# %%
autoencoder = Model(inputs, decoder(encoder(inputs)), name="autoencoder")
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  encoder (Functional)        (None, 2048)              8768448
#
#  decoder (Functional)        (None, 64, 64, 3)         8807363
#
# =================================================================
# Total params: 17,575,811
# Trainable params: 17,574,019
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
encoder.build(inputShape)
decoder.build(inputShape)
autoencoder.build(inputShape)

# %%
autoencoder.compile(loss="mse", optimizer=Adam(learning_rate=1e-3))

# %% [markdown]
# #Spliting datasets

# %%
checkpoint_path = "/content/drive/MyDrive/AutoEncoders/best_model_64.h5"
log_dir = "/content/logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
backup_dir = '/content/drive/MyDrive/AutoEncoders/backup.h5'

# %%
backups = BackupAndRestore(backup_dir, save_freq="epoch", delete_checkpoint=True, save_before_preemption=False)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='min')
tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_images=True, write_graph=True, update_freq='epoch',
                          profile_batch=0, embeddings_freq=0, embeddings_metadata=None, embeddings_data=None)
callbacks = [checkpoint]

# %% [markdown]
# i load the latest best model

# %%
filename = 'best_model.h5'
# !cp -r /content/drive/MyDrive/AutoEncoders/best_model_64.h5 /content/
print(f'The file {filename} was copied.')
# Out:
# The file best_model.h5 was copied.

# %% [markdown]
# if the file doesn't exist we just train from scratch

# %%
if os.path.exists(filename) and (not scratch):
    autoencoder.load_weights('/content/best_model.h5')
    print('weights loaded')
else:
  print('not loaded')
# Out:
# not loaded

# %%
EPOCHS = 50
Batch_Size = 128

# %%
train = np.load('/content/ae_train.npy')
validation = np.load('/content/ae_vali.npy')

# %%
history = autoencoder.fit(
		train,
		train,
		epochs=EPOCHS,
		validation_data=(validation, validation),
		batch_size = Batch_Size,
		callbacks=callbacks)
# Out:
# Epoch 1/50
# 279/279 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 1: val_loss improved from inf to 0.05533, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 84s 255ms/step - loss: 0.0216 - val_loss: 0.0553
# Epoch 2/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0105
# Epoch 2: val_loss improved from 0.05533 to 0.01573, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 75s 269ms/step - loss: 0.0105 - val_loss: 0.0157
# Epoch 3/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 3: val_loss improved from 0.01573 to 0.00840, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 4/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 4: val_loss improved from 0.00840 to 0.00788, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 260ms/step - loss: 0.0067 - val_loss: 0.0079
# Epoch 5/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 5: val_loss did not improve from 0.00788
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0058 - val_loss: 0.0084
# Epoch 6/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 6: val_loss did not improve from 0.00788
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0052 - val_loss: 0.0338
# Epoch 7/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0080
# Epoch 7: val_loss did not improve from 0.00788
# 279/279 [==============================] - 72s 259ms/step - loss: 0.0080 - val_loss: 0.0198
# Epoch 8/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 8: val_loss did not improve from 0.00788
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0050 - val_loss: 0.0114
# Epoch 9/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 9: val_loss improved from 0.00788 to 0.00555, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 10/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 10: val_loss did not improve from 0.00555
# 279/279 [==============================] - 72s 259ms/step - loss: 0.0041 - val_loss: 0.0151
# Epoch 11/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 11: val_loss improved from 0.00555 to 0.00417, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 261ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 12/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 12: val_loss improved from 0.00417 to 0.00415, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 13/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 13: val_loss improved from 0.00415 to 0.00350, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 263ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 14/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0034
# Epoch 14: val_loss improved from 0.00350 to 0.00341, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 74s 266ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 15/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 15: val_loss did not improve from 0.00341
# 279/279 [==============================] - 72s 259ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 16/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 16: val_loss did not improve from 0.00341
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0032 - val_loss: 0.0381
# Epoch 17/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0094
# Epoch 17: val_loss did not improve from 0.00341
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0094 - val_loss: 0.0135
# Epoch 18/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 18: val_loss did not improve from 0.00341
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 19/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 19: val_loss did not improve from 0.00341
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 20/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 20: val_loss did not improve from 0.00341
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0031 - val_loss: 0.0036
# Epoch 21/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 21: val_loss improved from 0.00341 to 0.00317, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 261ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 22/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 22: val_loss did not improve from 0.00317
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0029 - val_loss: 0.0097
# Epoch 23/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 23: val_loss did not improve from 0.00317
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 24/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 24: val_loss improved from 0.00317 to 0.00297, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 25/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0026
# Epoch 25: val_loss did not improve from 0.00297
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 26/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 26: val_loss improved from 0.00297 to 0.00288, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 261ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 27/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 27: val_loss improved from 0.00288 to 0.00268, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 28/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 28: val_loss did not improve from 0.00268
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 29/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0024
# Epoch 29: val_loss improved from 0.00268 to 0.00262, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 30/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 30: val_loss did not improve from 0.00262
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 31/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 31: val_loss did not improve from 0.00262
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0023 - val_loss: 0.0098
# Epoch 32/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 32: val_loss did not improve from 0.00262
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 33/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 33: val_loss did not improve from 0.00262
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 34/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 34: val_loss did not improve from 0.00262
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 35/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 35: val_loss did not improve from 0.00262
# 279/279 [==============================] - 72s 257ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 36/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 36: val_loss improved from 0.00262 to 0.00236, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 261ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 37/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 37: val_loss improved from 0.00236 to 0.00231, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 77s 275ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 38/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 38: val_loss improved from 0.00231 to 0.00219, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 261ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 39/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 39: val_loss did not improve from 0.00219
# 279/279 [==============================] - 72s 257ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 40/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0020
# Epoch 40: val_loss improved from 0.00219 to 0.00218, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 41/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 41: val_loss improved from 0.00218 to 0.00213, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 42/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 42: val_loss improved from 0.00213 to 0.00206, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 43/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 43: val_loss improved from 0.00206 to 0.00206, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 261ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 44/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 44: val_loss did not improve from 0.00206
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 45/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 45: val_loss did not improve from 0.00206
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 46/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 46: val_loss did not improve from 0.00206
# 279/279 [==============================] - 72s 258ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 47/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 47: val_loss did not improve from 0.00206
# 279/279 [==============================] - 76s 271ms/step - loss: 0.0023 - val_loss: 0.0056
# Epoch 48/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 48: val_loss did not improve from 0.00206
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 49/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 49: val_loss did not improve from 0.00206
# 279/279 [==============================] - 76s 272ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 50/50
# 278/279 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 50: val_loss improved from 0.00206 to 0.00185, saving model to /content/drive/MyDrive/AutoEncoders/best_model_64.h5
# 279/279 [==============================] - 73s 262ms/step - loss: 0.0018 - val_loss: 0.0018

# %%
del train
del validation

# %%
gc.collect()
# Out:
# 1808

# %%
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, history.history["loss"], label="train_loss")
plt.plot(N, history.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")

# %%
ae_test = np.load('/content/ae_test.npy')

# %%
autoencoder.load_weights('/content/drive/MyDrive/AutoEncoders/best_model_64.h5')

# %%
autoencoder.save('/content/drive/MyDrive/AutoEncoders/animeFaceModel.h5')

# %%
print("[INFO] making predictions...")
decoded = autoencoder.predict(ae_test)
outputs = None
# Out:
# [INFO] making predictions...
# 596/596 [==============================] - 14s 24ms/step

# %%
from sklearn.metrics import mean_squared_error
import random

# %%
mse = mean_squared_error(np.reshape(ae_test, (-1, 3)), np.reshape(decoded, (-1, 3)))
print(mse)
# Out:
# 0.001550879

# %%
decoded.shape
# Out:
# (19070, 64, 64, 3)

# %%
randimg = random.sample(range(decoded.shape[0]), 5)

# %%
fig, ax = plt.subplots(2, 5, figsize=(15, 6))
for i in range(2):
    for j in range(5):
      if i == 0:
        ax[i, j].imshow(ae_test[1*5 + randimg[j]])
        ax[i, j].axis('off')
        ax[i, j].set_title(f'Original Image {0*5 + j + 1}')
      else:
        ax[i, j].imshow(decoded[1*5 + randimg[j]])
        ax[i, j].axis('off')
        ax[i, j].set_title(f'Reconstructed Image {0*5 + j + 1}')

plt.show()

# %%
del ae_test
del decoded

# %%
gc.collect()
# Out:
# 25962
